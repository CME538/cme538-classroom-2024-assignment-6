# %% [markdown]
# # CME538 - Introduction to Data Science
# ## Tutorial 3 - Parsing HTML

# %% [markdown]
# ### Learning Objectives
# After completing this tutorial, you should be comfortable:
#
# - Understanding the overall structure of HTML tags
# - Finding the information of interest within a web-page by going through the HTML source code
# - Using Python and BeautifulSoup to extract the information of interest from HTML elements
#
# ### Turtorial Structure
# 1. [What is HTML](#section1)
# 2. [Scraping imdb.com](#section2)
# 3. [Scraping indeed.com](#section3)

# %% [markdown]
# <a id='section1'></a>
# # 1. What is HTML

# %% [markdown]
# source = https://www.w3schools.com/html/html_intro.asp

# %% [markdown]
# HTML stands for Hyper Text Markup Language
#
# HTML is the standard markup language for creating Web pages
#
# HTML describes the structure of a Web page
#
# HTML consists of a series of elements
#
# HTML elements tell the browser how to display the content
#
# HTML elements label pieces of content such as "this is a heading", "this is a paragraph", "this is a link", etc

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="400" align='left'/>
# </div>

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="200" align='left'/>
# </div>

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="700" align='left'/>
# </div>

# %% [markdown]
# <a id='section2'></a>
# # 2. Scraping imdb.com
# 'http://www.imdb.com/search/title?release_date=2017&sort=num_votes,desc&page=1'

# %%
from requests import get
response = ...

# %% [markdown]
# Let's see the text in `response`.

# %%
# Write your code here

# %% [markdown]
# To parse our HTML document, we’ll use a Python module called `BeautifulSoup`, the most common web scraping module for Python.
#
# Let's import `BeautifulSoup`.

# %%
import ....

# %% [markdown]
# Next, let's use ...

# %%
html_soup = ...

# %% [markdown]
# Let's the type and visualize the result

# %%
# Write your code here

# %% [markdown]
# `BeautifulSoup` provides a method called `find_all()` that allows us to extract the elements we are interested in. To use it we need to tell it the name of the tag we are interested in, and we can give it some attributes to make it more specific.
#
# Let's learn more about `find_all()` by using the built-in `help` function.

# %%
help(html_soup.find_all)

# %%
result_set = html_soup.find_all()

first_movie = ...

# %% [markdown]
# `first_movie` is a Tag object, and the various HTML tags within it are stored as its attributes. We can access them just like we would access any attribute of a Python object. However, using a tag name as an attribute will only select the first tag by that name. If we run first_movie.div, we only get the content of the first div tag:

# %% [markdown]
# First, try to export the tags treating them like python objects

# %%
# Write your code here

# %% [markdown]
# Now try to export the tags using the find_all function

# %%
# Write your code here

# %% [markdown]
# Export the name of the movie

# %%
first_name = # Write your code here

# %% [markdown]
# Export the year of the movie

# %%
first_year = # Write your code here

# %% [markdown]
# Export the imdb_score of the movie

# %%
first_imdb = # Write your code here

# %% [markdown]
# Export the meta score of the movie

# %%
first_metascore = # Write your code here

# %% [markdown]
#  Export the number of votes of the movie

# %%
first_votes = # Write your code here

# %% [markdown]
# ##### Putting everything together, we can extract information of interest on each movie and store them in a single pandas dataframe

# %%
import pandas as pd

# %% [markdown]
# Let's create some lists to store the scraped data in and write our loop to iterate over every ovie object
#
# Extract data from individual movie containers and use an if condition to make sure that the movie element has Meta score

# %%
names = []
years = []
imdb_ratings = []
metascores = []
votes = []

for # Write your code here:
    if # Write your code here:
        # Write your code here

# %% [markdown]
# <a id='section3'></a>
# # 3. Scraping indeed.com
# #### now let's repeat the process for another URL

# %%
URL = "https://ca.indeed.com/jobs?q=data%20science&l=Toronto%2C%20ON&vjk=2711e3e45b8c8770"
page = 
soup = 

soup.find_all()
