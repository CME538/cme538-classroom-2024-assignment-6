# %% [markdown]
# # CME538 - Introduction to Data Science
# ## Lecture 5.1 - Time Series Data

# %% [markdown]
# ## Setup Notebook

# %%
# Import 3rd party libraries
import datetime
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt

# Configure Notebook
# %matplotlib inline
plt.style.use('fivethirtyeight')
sns.set_context("notebook")
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Stacked Overflow Questions

# %%
stacked_overflow = pd.read_csv('stacked_overflow.csv')
stacked_overflow['month'] = pd.to_datetime(stacked_overflow['month'], format='%y-%b')
stacked_overflow.head()
# Out:
#        month  nltk  spacy  stanford-nlp  python   r  numpy  scipy  matlab  \
# 0 2009-01-01     0      0             0     631   8      6      2      19
# 1 2009-02-01     1      0             0     633   9      7      3      27
# 2 2009-03-01     0      0             0     766   4      4      2      24
# 3 2009-04-01     0      0             0     768  12      6      3      32
# 4 2009-05-01     1      0             0    1003   2      7      2      42
#
#    machine-learning  ...  Plato  Sympy  Flair  stanford-nlp.1  pyqt  Nolearn  \
# 0                 8  ...      0      1      0               0     5        0
# 1                 4  ...      0      0      0               0     5        0
# 2                 3  ...      0      0      0               0     7        0
# 3                10  ...      0      0      0               0    11        0
# 4                 7  ...      0      0      0               0    10        0
#
#    Lasagne  OCR  Apache-spark-mlib  azure-virtual-machine
# ...

# %%
# Write your code here.
plt.figure(figsize=(10, 5))
plt.title('Stacked Overflow Questions\nData Science Programming Languages/Libraries', fontsize=18)
ax = sns.lineplot(data=stacked_overflow, x='month', y='python', label='Python')
sns.lineplot(ax=ax, data=stacked_overflow, x='month', y='r', label='R')
sns.lineplot(ax=ax, data=stacked_overflow, x='month', y='matlab', label='Matlab')
sns.lineplot(ax=ax, data=stacked_overflow, x='month', y='pandas', label='Pandas')
ax.legend(fontsize=14)
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)
ax.set_xlabel('Date-Time', fontsize=18)
ax.set_ylabel('Question Count', fontsize=18)
plt.show()

# %%
# Write your code here.
plt.figure(figsize=(10, 5))
plt.title('Stacked Overflow Questions\nData Science Programming Languages/Libraries', fontsize=18)
ax = sns.lineplot(data=stacked_overflow, x='month', y='matlab', label='Matlab')
ax.legend(fontsize=14)
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)
ax.set_xlabel('Date-Time', fontsize=18)
ax.set_ylabel('Question Count', fontsize=18)
plt.show()

# %% [markdown]
# # 2. S&P500

# %%
# !pip install yfinance

# %%
import yfinance as yf

# %%
sp500 = yf.download('SPY')
sp500['change'] = sp500['Close'].diff()
sp500.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close   Volume  \
# Date
# 1993-01-29  43.96875  43.96875  43.75000  43.93750  25.968958  1003200
# 1993-02-01  43.96875  44.25000  43.96875  44.25000  26.153660   480500
# 1993-02-02  44.21875  44.37500  44.12500  44.34375  26.209057   201300
# 1993-02-03  44.40625  44.84375  44.37500  44.81250  26.486113   529400
# 1993-02-04  44.96875  45.09375  44.46875  45.00000  26.596937   531500
#
#              change
# Date
# 1993-01-29      NaN
# 1993-02-01  0.31250
# 1993-02-02  0.09375
# 1993-02-03  0.46875
# 1993-02-04  0.18750

# %%
# Write your code here.
plt.figure(figsize=(10, 5))
plt.title('S&P 500 Daily Closing Price', fontsize=18)
ax = sns.lineplot(data=sp500, x=sp500.index, y='Close', label='S&P 500')
ax.legend(fontsize=14)
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)
ax.set_xlabel('Date-Time', fontsize=18)
ax.set_ylabel('Closing Price', fontsize=18)
plt.show()

# %%
# Write your code here.
plt.figure(figsize=(10, 5))
plt.title('S&P 500 Daily Change', fontsize=18)
ax = sns.lineplot(data=sp500, x=sp500.index[0:], y='change', label='S&P 500')
ax.legend(fontsize=14)
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)
ax.set_xlabel('Date-Time', fontsize=18)
ax.set_ylabel('Daily Change', fontsize=18)
plt.show()

# %%
# Write your code here.
plt.figure(figsize=(10, 5))
plt.title('S&P 500 Daily Closing Price', fontsize=18)
ax = sns.lineplot(data=sp500, x=sp500.index, y='Close', label='S&P 500')
ax.legend(fontsize=14)
ax.set_xlim([datetime.date(2013, 1, 1), datetime.date(2015, 1, 1)])
ax.set_ylim([140, 220])
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)
ax.set_xlabel('Date-Time', fontsize=18)
ax.set_ylabel('Closing Price', fontsize=18)
plt.show()

# %% [markdown]
# # 3. Bike Traffic Data

# %%
bike_data = pd.read_csv('bike_traffic_data.csv')
bike_data['Date'] = pd.to_datetime(bike_data['Date'])
bike_data.head()
# Out:
#                  Date  Fremont Bridge West Sidewalk  \
# 0 2012-10-03 00:00:00                           9.0
# 1 2012-10-03 01:00:00                           6.0
# 2 2012-10-03 02:00:00                           1.0
# 3 2012-10-03 03:00:00                           3.0
# 4 2012-10-03 04:00:00                           1.0
#
#    Fremont Bridge East Sidewalk
# 0                           4.0
# 1                           4.0
# 2                           1.0
# 3                           2.0
# 4                           6.0

# %%
# Write your code here.
plt.figure(figsize=(10, 5))
plt.title('Fremont Bridge Bike Traffic', fontsize=18)
ax = sns.lineplot(data=bike_data, x='Date', y='Fremont Bridge West Sidewalk')
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)
ax.set_xlabel('Date-Time', fontsize=18)
ax.set_ylabel('Hourly Crossings', fontsize=18)
plt.show()

# %% [markdown]
# # 4. Canada COVID Cases

# %%
canada_covid = pd.read_csv('covid19_canada.csv')
canada_covid = canada_covid[canada_covid['prname'] == 'Canada']
canada_covid['date'] = pd.to_datetime(canada_covid['date'])
canada_covid.head()
# Out:
#     pruid  prname prnameFR       date  update  numconf  numprob  numdeaths  \
# 2       1  Canada   Canada 2020-01-31     NaN        4        0        0.0
# 5       1  Canada   Canada 2020-02-08     NaN        7        0        0.0
# 8       1  Canada   Canada 2020-02-16     NaN        8        0        0.0
# 11      1  Canada   Canada 2020-02-21     NaN        9        0        0.0
# 14      1  Canada   Canada 2020-02-24     NaN       10        0        0.0
#
#     numtotal  numtested  ...  numdeaths_last14  ratedeaths_last14  \
# 2          4        NaN  ...               NaN                NaN
# 5          7        NaN  ...               NaN                NaN
# 8          8        NaN  ...               NaN                NaN
# 11         9        NaN  ...               NaN                NaN
# 14        10        NaN  ...               NaN                NaN
#
#     numtotal_last7  ratetotal_last7  numdeaths_last7  ratedeaths_last7  \
# ...

# %%
# Write your code here.
plt.figure(figsize=(10, 5))
plt.title('Daily COVID-19 Cases in Canada', fontsize=18)
ax = sns.lineplot(data=canada_covid, x='date', y='avgtotal_last7')
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)
ax.set_xlabel('Date-Time', fontsize=18)
ax.set_ylabel('Daily Cases', fontsize=18)
plt.show()

# %% [markdown]
# # 5. Earthquakes

# %%
earthquakes = pd.read_csv('earthquakes.csv')
earthquakes = earthquakes.set_index(pd.to_datetime(earthquakes['time']))
earthquakes = earthquakes.resample('M').count()
earthquakes.head()
# Out:
#                            time  latitude  longitude  depth  mag  magType  \
# time
# 1973-03-31 00:00:00+00:00     1         1          1      1    1        1
# 1973-04-30 00:00:00+00:00     0         0          0      0    0        0
# 1973-05-31 00:00:00+00:00     1         1          1      1    0        0
# 1973-06-30 00:00:00+00:00     0         0          0      0    0        0
# 1973-07-31 00:00:00+00:00     0         0          0      0    0        0
#
#                            nst  gap  dmin  rms  ...  updated  place  type  \
# time                                            ...
# 1973-03-31 00:00:00+00:00    0    0     0    0  ...        1      1     1
# 1973-04-30 00:00:00+00:00    0    0     0    0  ...        0      0     0
# 1973-05-31 00:00:00+00:00    0    0     0    0  ...        1      1     1
# 1973-06-30 00:00:00+00:00    0    0     0    0  ...        0      0     0
# 1973-07-31 00:00:00+00:00    0    0     0    0  ...        0      0     0
#
# ...

# %%
# Write your code here.
plt.figure(figsize=(10, 5))
plt.title('Daily Earthquakes in Oklahoma', fontsize=18)
ax = sns.lineplot(data=earthquakes, x=earthquakes.index, y='time')
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)
ax.set_xlabel('Date-Time', fontsize=18)
ax.set_ylabel('Daily Eqarthquakes', fontsize=18)
plt.show()

# %% [markdown]
# # 6. Land Temperature

# %%
city_temperatures = pd.read_csv('city_temperatures.csv')
city_temperatures['dt'] = pd.to_datetime(city_temperatures['dt'])
city_temperatures = city_temperatures.set_index(city_temperatures['dt'])
city_temperatures.head()
# Out:
#                    dt  AverageTemperature  AverageTemperatureUncertainty  \
# dt
# 1841-01-01 1841-01-01              19.101                          4.244
# 1841-02-01 1841-02-01              19.744                          2.995
# 1841-03-01 1841-03-01              16.611                          4.420
# 1841-04-01 1841-04-01              12.269                          1.766
# 1841-05-01 1841-05-01              10.275                          1.188
#
#                  City    Country Latitude Longitude
# dt
# 1841-01-01  Melbourne  Australia   37.78S   144.41E
# 1841-02-01  Melbourne  Australia   37.78S   144.41E
# 1841-03-01  Melbourne  Australia   37.78S   144.41E
# 1841-04-01  Melbourne  Australia   37.78S   144.41E
# 1841-05-01  Melbourne  Australia   37.78S   144.41E

# %%
city_temperatures_yearly = city_temperatures['AverageTemperature'].rolling(window=12).mean().to_frame()

# %%
# Write your code here.
plt.figure(figsize=(10, 5))
plt.title('Daily Temperature in Melbourne', fontsize=18)
ax = sns.lineplot(data=city_temperatures, x='dt', y='AverageTemperature', label='Monthly')
ax = sns.lineplot(data=city_temperatures_yearly, x=city_temperatures_yearly.index, y='AverageTemperature', label='Yearly')
ax.legend(fontsize=14)
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)
ax.set_xlabel('Date-Time', fontsize=18)
ax.set_ylabel('Temperature, °C', fontsize=18)
plt.show()

# %%
# Write your code here.
plt.figure(figsize=(10, 5))
plt.title('Daily Temperature in Melbourne\n(12 month rolling average)', fontsize=18)
# ax = sns.lineplot(data=city_temperatures, x='dt', y='AverageTemperature', label='Monthly')
ax = sns.lineplot(data=city_temperatures_yearly, x=city_temperatures_yearly.index, y='AverageTemperature', label='Yearly')
ax.legend(fontsize=14)
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)
ax.set_xlabel('Date-Time', fontsize=18)
ax.set_ylabel('Temperature, °C', fontsize=18)
plt.show()

# %% [markdown]
# # 7. Lynx Trappings

# %%
lynx = pd.read_csv('Annual_Canadian_Lynx_trappings.csv', index_col=0)
lynx.head()
# Out:
#    X  time  value
# 1  1  1821    269
# 2  2  1822    321
# 3  3  1823    585
# 4  4  1824    871
# 5  5  1825   1475

# %%
# Write your code here.
plt.figure(figsize=(10, 5))
plt.title('Annual Lynx Trappings in Canada', fontsize=18)
ax = sns.lineplot(data=lynx, x='time', y='value', marker='o')
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)
ax.set_xlabel('Date-Time', fontsize=18)
ax.set_ylabel('Annual Trappings', fontsize=18)
plt.show()

# %%
lag = 11

fig, axs = plt.subplots(nrows=3, figsize=(8, 12))
axs[0].set_title('Autocorrelation Lag: {}'.format(lag), fontsize=16)
axs[0].plot(lynx['time'], lynx['value'], '-o', ms=10);
axs[0].plot(lynx['time']+lag, lynx['value'], '-o');
axs[0].set_xlim([1821, 1934])
axs[0].set_ylabel('Annual Trappings', fontsize=14)
axs[0].set_xlabel('Date-Time', fontsize=14)

corr = np.corrcoef(lynx['value'].iloc[0:-lag], lynx['value'].iloc[lag:])[0, 1]
axs[1].set_title('Correlation: {}'.format(np.round(corr, 2)), fontsize=16)
axs[1].plot(lynx['value'].iloc[0:-lag], lynx['value'].iloc[lag:], '.');
axs[1].set_aspect('equal', 'box')
axs[1].set_xlabel('Annual Trappings', fontsize=14)
axs[1].set_ylabel('Annual Trappings (lag: {})'.format(lag), fontsize=14)

lags = np.arange(0, lag+1)
corrs = [1]
corrs.extend([np.corrcoef(lynx['value'].iloc[0:-lag], lynx['value'].iloc[lag:])[0, 1] for lag in lags[1:]])
axs[2].set_xlabel('Lag', fontsize=14)
axs[2].set_ylabel('Autocorrelation', fontsize=14)
axs[2].set_xlim([0, 11])
axs[2].set_ylim([-1, 1])

axs[2].plot(lags, corrs, '-o')

# Narrow the gap between the plots
plt.subplots_adjust(hspace=0.35)

# %%
pd.plotting.autocorrelation_plot(lynx['value']);

# %% [markdown]
# # 8. Brick Production

# %%
bricks = pd.read_csv('brick_production.csv', names=['val'])
bricks['date'] = pd.date_range('8/1/1955', '6/1/1994', freq='Q')
bricks.head()
# Out:
#    val       date
# 0  189 1955-09-30
# 1  204 1955-12-31
# 2  208 1956-03-31
# 3  197 1956-06-30
# 4  187 1956-09-30

# %%
# Write your code here.
plt.figure(figsize=(10, 5))
plt.title('Australian Quarterly Clay Brick Production: 1956–1994', fontsize=18)
ax = sns.lineplot(data=bricks, x='date', y='val', marker='o')
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)
ax.set_xlabel('Date-Time', fontsize=18)
ax.set_ylabel('Million Units', fontsize=18)
plt.show()

# %% [markdown]
# # 9. White Noise

# %%
white_noise = pd.DataFrame({'values': np.random.rand(100)})

# %%
plt.figure(figsize=(10, 5))
ax = sns.lineplot(data=white_noise, marker='o');

# %%
pd.plotting.autocorrelation_plot(white_noise);

# %% [markdown]
# # 10. Red Meat Slaughter

# %%
red_meat = pd.read_csv('monthly_red_meat_slaughter.csv')
red_meat['EndDt_DtFin'] = pd.to_datetime(red_meat['EndDt_DtFin'])
red_meat.head()
# Out:
#   EndDt_DtFin MjrCmdtyEn_PrdtPrncplAn MjCmdtyFr_PrdtPrncplFr CtgryEn_CtgrieAn  \
# 0  1998-01-24                  Calves                  Veaux           Female
# 1  1998-01-24                  Calves                  Veaux             Male
# 2  1998-01-24                  Cattle                 Bovins            Bulls
# 3  1998-01-24                  Cattle                 Bovins             Cows
# 4  1998-01-24                  Cattle                 Bovins          Heifers
#
#   CtgryFr_CtgrieFr  NumHd_NmbTetes
# 0          Femelle            4834
# 1             Male           18627
# 2         Taureaux            1618
# 3           Vaches           49722
# 4         Genisses           73843

# %%
cattle = red_meat[red_meat['MjrCmdtyEn_PrdtPrncplAn'] == 'Cattle']
cattle = cattle.set_index('EndDt_DtFin')
cattle = cattle.groupby(cattle.index).sum()
cattle.head()
# Out:
#              NumHd_NmbTetes
# EndDt_DtFin
# 1998-01-24           243028
# 1998-02-21           248279
# 1998-03-28           296578
# 1998-04-25           245290
# 1998-05-23           263970

# %%
# Write your code here.
plt.figure(figsize=(10, 5))
plt.title('Monthly Cattle Slaughtered in Canada', fontsize=18)
ax = sns.lineplot(data=cattle, x=cattle.index, y='NumHd_NmbTetes', marker='o')
ax.xaxis.set_tick_params(labelsize=14)
ax.yaxis.set_tick_params(labelsize=14)
ax.set_xlim([datetime.date(1998, 1, 1), datetime.date(2003, 1, 1)])
ax.set_ylim([240000, 380000])
ax.set_xlabel('Date-Time', fontsize=18)
ax.set_ylabel('Cattle Slaughtered', fontsize=18)
plt.show()

# %%
plt.figure(figsize=(10, 5))
pd.plotting.autocorrelation_plot(cattle.loc['1998-01-01':'2003-01-01']);

# %% [markdown]
# # 11. Stationarity

# %%
time_series = pd.DataFrame({'values': np.random.randn(1000)})

# %%
plt.figure(figsize=(10, 5))
ax = sns.lineplot(data=time_series);

# %%
time_series = pd.DataFrame({'values': np.random.randn(1000) * np.arange(1000) * 0.1})

# %%
plt.figure(figsize=(10, 5))
ax = sns.lineplot(data=time_series);

# %%
time_series = pd.DataFrame({'values': 20 * np.random.randn(1000) + np.arange(1000) * 0.1})

# %%
plt.figure(figsize=(10, 5))
ax = sns.lineplot(data=time_series);

# %%
time_series = np.random.uniform(-1, 1, 1000).cumsum()

# %%
plt.figure(figsize=(10, 5))
ax = sns.lineplot(data=time_series);

# %%
time_series_diff = np.diff(time_series)

# %%
plt.figure(figsize=(10, 5))
ax = sns.lineplot(data=time_series_diff);
